# %%
import matplotlib.pyplot as plt
plt.style.use(['dark_background'])
import seaborn as sns
plt.style.use("dark_background")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# '/Users/christianklaus/code/christianklausML/dispatcher-project/notebooks'

# %%
csv_path = os.path.join('..','raw_data', 'reduced')
csv_path
# Out:
# '../raw_data/reduced'

# %%
order = pd.read_csv(os.path.join(csv_path, 'order.csv'))
order
# Out:
#                 ID  SHOP_ID          SHOP_ORDER_DATE  \
# 0        152860496      196  2022-03-17 15:03:53.000
# 1        152860497      196  2022-03-17 15:03:53.000
# 2        152860498      196  2022-03-17 15:03:53.000
# 3        152860499      196  2022-03-17 15:03:53.000
# 4        152860500      196  2022-03-17 15:03:53.000
# ...            ...      ...                      ...
# 1557787  152379005      196  2022-03-14 20:13:33.000
# 1557788  152379007      196  2022-03-14 20:13:33.000
# 1557789  152379010      196  2022-03-14 20:13:33.000
# 1557790  152379011      196  2022-03-14 20:13:33.000
# 1557791  152379014      196  2022-03-14 20:13:33.000
#
#          MINIMUM_NUMBERS_OF_SHIPMENTS  BOARDING_COMPLETE LANGUAGE      STATE  \
# 0                                   1                NaN      NaN  completed
# 1                                   1                NaN      NaN  completed
# 2                                   1                NaN      NaN  completed
# ...

# %%
carrier = pd.read_csv(os.path.join(csv_path, 'carrier.csv'))
carrier
# Out:
#       ID  COUNTRY_ID  CARRIER_COMPANY_ID  NOTIFICATION_GAP_IN_MIN
# 0      1         216                  34                     1440
# 1      2         216                  13                     1440
# 2      3         216                  37                     1440
# 3      4         216                  12                     1440
# 4      5          15                  24                     1440
# ..   ...         ...                 ...                      ...
# 159  179         157                  53                     1440
# 160  180         157                  24                     1440
# 161  181          61                  83                     1440
# 162  182          61                  84                     1440
# 163  183         110                  85                     1440
#
# [164 rows x 4 columns]

# %%
ticket = pd.read_csv(os.path.join(csv_path, 'ticket.csv'))

# %%
ticket.head(10)
# Out:
#            ID  SHIPMENT_ID  STATUS_ID  NOTES  TYPE_ID  \
# 0  1991335581  170551890.0        NaN    NaN       38
# 1  1991335583  170551890.0        NaN    NaN       33
# 2  1991335585  171118033.0        NaN    NaN       38
# 3  1991335586  171118033.0        NaN    NaN       34
# 4  1991350152  169424918.0        NaN    NaN        5
# 5  1991357025          NaN        NaN    NaN       85
# 6  1991357660          NaN        NaN    NaN      107
# 7  1991361945  170377244.0        NaN    NaN       38
# 8  1991361946  170377244.0        NaN    NaN       33
# 9  1991373580  172093646.0        NaN    NaN       38
#
#                  CREATEDAT  SHIPMENT_TIMELINE_ID STATUS  \
# 0  2022-05-13 05:31:35.000           994191806.0    new
# 1  2022-05-13 05:31:35.000           994191806.0    new
# 2  2022-05-13 05:31:36.000           994191808.0    new
# 3  2022-05-13 05:31:36.000           994191808.0    new
# 4  2022-05-13 05:43:53.000           994199312.0    new
# ...

# %%
carrier['ID'].nunique()

# %%
ticket['SHOP_ID'].nunique()

# %%
ticket['SHIPMENT_ID'].nunique()

# %%
ticket.describe()

# %% [markdown]
# * 102 unique shops
# * 1,692,220 unique shipments
# * 162 unique carriers
